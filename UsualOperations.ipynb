# %% [markdown]
# ## update all securities

# %%
from DatabaseManagement import *
for i in tqdm(securities.keys()):
    update_data(i)
# Out:
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
# [*********************100%***********************]  1 of 1 completed
#  17%|██████████████                                                                      | 1/6 [00:01<00:08,  1.60s/it]
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-09  155.490005  156.110001  153.949997  154.070007  154.070007
# 2021-09-10  155.000000  155.479996  148.699997  148.970001  148.970001
# 2021-09-13  150.630005  151.419998  148.750000  149.550003  149.550003
# 2021-09-14  150.350006  151.070007  146.910004  148.119995  148.119995
# 2021-09-15  148.559998  149.440002  146.369995  149.029999  149.029999
# 2021-09-16  148.440002  148.970001  147.220001  148.789993  148.789993
# 2021-09-17  148.820007  148.820007  145.759995  146.059998  146.059998
# 2021-09-20  143.800003  144.839996  141.270004  142.940002  142.940002
# ...

# %% [markdown]
# ## Check Holdings

# %%
get_data('holdings')
# Out:
#                   Date Security  Price  Amount
# 0  2020-02-13 00:00:00     AAPL  135.0    10.0
# 1  2020-02-13 00:00:00     AAPL  135.0    10.0
# 2  2021-08-11 00:00:00     TSLA  708.0     3.0
# 3  2020-02-13 00:00:00      DJI    0.0     0.0
# 4  2021-01-15 00:00:00      SZC    0.0     0.0
# 5  2021-08-25 00:00:00    TCEHY    0.0   300.0
# 6  2020-02-13 00:00:00      SZC    0.0     0.0
# 7  2020-02-13 00:00:00     SSEC    0.0     0.0

# %%
con = sql.connect('stock')
cur = con.cursor()
cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
print(cur.fetchall())
con.close()
# Out:
# [('AAPL',), ('DJI',), ('SSEC',), ('SZC',), ('TCEHY',), ('TSLA',), ('holdings',)]

# %% [markdown]
# ## Add record

# %%
record_operation('2020-02-13','SSEC',0,0)
